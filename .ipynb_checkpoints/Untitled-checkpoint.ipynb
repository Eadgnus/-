# %%
import os

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.2.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\users\eadgnus\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas as pd

# %%
pross_20 = pd.read_csv('\\Users\\eaDgnuS\\Desktop\\북극곰\\20년폐기물처리현황(톤년).csv')

# %%
pross_20
# Out:
#      Unnamed: 0     지역           처리방식       종류   세부종류          소계        재활용  \
# 0             0  구분(1)          구분(2)    구분(3)  구분(4)         발생량        처리량
# 1             1  구분(1)          구분(2)    구분(3)  구분(4)          소계        재활용
# 2             2     전국             합계       소계     소계  17303386.4  9762502.9
# 3             3     전국   종량제방식 등 혼합배출       소계     소계   8041965.2   900093.2
# 4             4     전국   종량제방식 등 혼합배출      가연성     소계   6929046.9   823543.8
# ..          ...    ...            ...      ...    ...         ...        ...
# 753         753     제주  재활용 가능자원 분리배출  폐전기전자제품     소계      5676.0     5676.0
# 754         754     제주  재활용 가능자원 분리배출     폐가구류     소계         0.0        0.0
# 755         755     제주  재활용 가능자원 분리배출       기타     소계     17468.9    17468.9
# 756         756     제주  재활용 가능자원 분리배출  재활용 잔재물     소계     12997.3        0.0
# 757         757     제주  음식물류 폐기물 분리배출       소계     소계     81232.2    81232.2
#
#             소각         매립       기타
# ...

# %%
ps = pd.read_csv('\\Users\\eaDgnuS\\Desktop\\북극곰\\폐기물_지역별처리현황_10년(톤일).csv', encoding='cp949')

# %%
ps.head(30)
# Out:
#     시도(1)     2010  2010.1  2010.2   2010.3   2010.4  2010.5  2010.6   2010.7  \
# 0   시도(1)       총계      총계      총계       총계   지방자치단체  지방자치단체  지방자치단체   지방자치단체
# 1   시도(1)        계      매립      소각      재활용       소계      매립      소각      재활용
# 2      합계  40920.4  6989.8  9629.9  24300.7  26857.4  6485.4  8035.1  12336.9
# 3      서울   8393.6  1033.9  1820.8   5538.9   4338.2   681.1  1050.3   2606.8
# 4      부산   2638.6   223.4   512.7   1902.5   1760.9   223.4   512.7   1024.8
# 5      대구   2015.7   486.0   315.5   1214.2   1196.7   486.0   315.5    395.2
# 6      인천   1863.4   145.3   596.9   1121.2    228.3    26.4    32.7    169.2
# 7      광주   1238.4   235.2   231.9    771.3    982.2   235.2   231.9    515.1
# 8      대전   1295.5   203.6   242.8    849.1    620.2   203.6   242.8    173.8
# 9      울산    907.4   101.2   209.3    596.9    907.4   101.2   209.3    596.9
# 10     세종        -       -       -        -        -       -       -        -
# ...

# %%
ps2010 = ps.filter(regex='^2010')

# %%
ps2010.columns
# Out:
# Index(['2010', '2010.1', '2010.2', '2010.3', '2010.4', '2010.5', '2010.6',
#        '2010.7', '2010.8', '2010.9', '2010.10', '2010.11', '2010.12',
#        '2010.13', '2010.14', '2010.15'],
#       dtype='object')

# %%
for i in ps2010.columns:
    if ps2010[i].iloc[1] == '소각':
        print(f'지역{ps2010.iloc[1]} rwewr소각: {ps2010[i]}t')
# Out:
# 지역2010         계
# 2010.1      매립
# 2010.2      소각
# 2010.3     재활용
# 2010.4      소계
# 2010.5      매립
# 2010.6      소각
# 2010.7     재활용
# 2010.8      소계
# 2010.9      매립
# 2010.10     소각
# 2010.11    재활용
# 2010.12     소계
# 2010.13     매립
# 2010.14     소각
# 2010.15    재활용
# Name: 1, dtype: object rwewr소각: 0         총계
# 1         소각
# 2     9629.9
# 3     1820.8
# 4      512.7
# 5      315.5
# 6      596.9
# 7      231.9
# 8      242.8
# 9      209.3
# 10         -
# 11    2767.9
# 12     137.0
# 13     390.1
# 14     464.7
# 15     226.2
# 16     273.2
# 17     388.8
# 18     882.5
# 19     169.6
# Name: 2010.2, dtype: objectt
# 지역2010         계
# 2010.1      매립
# 2010.2      소각
# 2010.3     재활용
# 2010.4      소계
# 2010.5      매립
# 2010.6      소각
# 2010.7     재활용
# 2010.8      소계
# 2010.9      매립
# 2010.10     소각
# 2010.11    재활용
# 2010.12     소계
# 2010.13     매립
# 2010.14     소각
# 2010.15    재활용
# Name: 1, dtype: object rwewr소각: 0     지방자치단체
# 1         소각
# 2     8035.1
# ...
